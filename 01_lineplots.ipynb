# %% [markdown]
# ## Study the data of Iris with the help of Lineplots

# %% [markdown]
# |Step-1|
# |------|
#
#
# ### Import these libararies

# %% [markdown]
# - seaborn
# - matplotlib
# - pandas
# - numpy
# - scipy

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %% [markdown]
# |Step-2|
# |------|
#
# ### Load_dataset

# %%
flower=sns.load_dataset("iris")
flower
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# |Step-3|
# |------|
# ### Making a plot

# %%
sns.lineplot(x="sepal_length",y="sepal_width",data =flower)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ### How to add a title?

# %%
sns.lineplot(x="sepal_length",y="sepal_width",data =flower)
plt.title("flower Data")
plt.title
# Out:
# <function matplotlib.pyplot.title(label, fontdict=None, loc=None, pad=None, *, y=None, **kwargs)>

# %% [markdown]
# ### How to limit a Plot?

# %%
sns.lineplot(x="sepal_length",y="sepal_width",data =flower)
plt.xlim(2)
plt.ylim(1)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ### How to increase or decrease figure size ?

# %%
plt.figure(figsize=(2,3))
sns.lineplot(x="sepal_length",y="sepal_width",data =flower)
plt.title("flower plot")
sns.set_style(style=None,rc=None)
sns.set_style("dark")

# %%
plt.figure(figsize=(2,4))
sns.lineplot(x="sepal_length",y="sepal_width",data =flower)
plt.title("flower plot")
sns.set_style(style=None,rc=None)
sns.set_style("dark")
